# %%
# !pip install facenet-pytorch opencv-python torch torchvision
# Out:
# Collecting facenet-pytorch
#   Using cached facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: opencv-python in c:\users\hp g1\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: torch in c:\users\hp g1\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: torchvision in c:\users\hp g1\anaconda3\lib\site-packages (0.23.0)
# Collecting torchvision
#   Using cached torchvision-0.17.2-cp39-cp39-win_amd64.whl (1.2 MB)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in c:\users\hp g1\anaconda3\lib\site-packages (from facenet-pytorch) (1.26.4)
# Requirement already satisfied: Pillow<10.3.0,>=10.2.0 in c:\users\hp g1\anaconda3\lib\site-packages (from facenet-pytorch) (10.2.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in c:\users\hp g1\anaconda3\lib\site-packages (from facenet-pytorch) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\hp g1\anaconda3\lib\site-packages (from facenet-pytorch) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp g1\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: fsspec in c:\users\hp g1\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: jinja2 in c:\users\hp g1\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: networkx in c:\users\hp g1\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: sympy in c:\users\hp g1\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: filelock in c:\users\hp g1\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp g1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp g1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (1.26.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp g1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp g1\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.3)
# Requirement already satisfied: colorama in c:\users\hp g1\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.0.0->facenet-pytorch) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp g1\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp g1\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Installing collected packages: torchvision, facenet-pytorch
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.23.0
#     Uninstalling torchvision-0.23.0:
#       Successfully uninstalled torchvision-0.23.0
# Successfully installed facenet-pytorch-2.6.0 torchvision-0.17.2

# %%
import torch
from facenet_pytorch import MTCNN, InceptionResnetV1
import cv2
from PIL import Image
import numpy as np
import os

# Check if GPU is available
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# mtcnn: for detection; resnet: for recognition (FaceNet)
mtcnn = MTCNN(keep_all=True, device=device)
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)
# Out:
#   0%|          | 0.00/107M [00:00<?, ?B/s]

# %%
def build_database(data_path):
    database = {}
    for person_name in os.listdir(data_path):
        person_dir = os.path.join(data_path, person_name)
        embeddings = []
        for img_name in os.listdir(person_dir):
            img = Image.open(os.path.join(person_dir, img_name))
            # MTCNN crops and resizes face automatically
            face = mtcnn(img)
            if face is not None:
                # Generate embedding (1st face in image)
                emb = resnet(face[0].unsqueeze(0).to(device)).detach().cpu().numpy()
                embeddings.append(emb)
        
        # Store the average embedding for the person for stability
        if embeddings:
            database[person_name] = np.mean(embeddings, axis=0)
    return database

# Usage:
# known_faces = build_database('path_to_team_images')

# %%
def live_recognition(database, threshold=0.8):
    cap = cv2.VideoCapture(0)
    
    while True:
        ret, frame = cap.read()
        img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        
        # Detect all faces in frame
        boxes, _ = mtcnn.detect(img)
        
        if boxes is not None:
            faces = mtcnn(img)
            for i, box in enumerate(boxes):
                # Get embedding for detected face
                face_emb = resnet(faces[i].unsqueeze(0).to(device)).detach().cpu().numpy()
                
                # Compare with database
                min_dist = 100
                identity = "Unknown"
                
                for name, db_emb in database.items():
                    dist = np.linalg.norm(face_emb - db_emb) # Euclidean Distance
                    if dist < min_dist:
                        min_dist = dist
                        identity = name if dist < threshold else "Unknown"
                
                # Draw GUI elements
                x, y, w, h = box.astype(int)
                color = (0, 255, 0) if identity != "Unknown" else (0, 0, 255)
                cv2.rectangle(frame, (x, y), (w, h), color, 2)
                cv2.putText(frame, f"{identity} ({min_dist:.2f})", (x, y-10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        cv2.imshow('Lab S2-B5C-02: Face Recognition', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'): break

    cap.release()
    cv2.destroyAllWindows()

# %%
# 1. Define the path to the folder containing your team's images
# (Make sure each person has their own subfolder with >10 images as per the assignment)
dataset_path = 'path_to_team_images' 

# 2. Build the database of known faces
print("Building database...")
known_faces_db = build_database(dataset_path)
print(f"Database built with {len(known_faces_db)} known individuals.")

# 3. Start the live webcam recognition
print("Starting live recognition...")
live_recognition(known_faces_db, threshold=0.8)
# Out:
# Building database...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3480\1334644022.py in <module>
#       5 # 2. Build the database of known faces
#       6 print("Building database...")
# ----> 7 known_faces_db = build_database(dataset_path)
#       8 print(f"Database built with {len(known_faces_db)} known individuals.")
#       9
#
# ~\AppData\Local\Temp\ipykernel_3480\1480263948.py in build_database(data_path)
#       1 def build_database(data_path):
#       2     database = {}
# ----> 3     for person_name in os.listdir(data_path):
#       4         person_dir = os.path.join(data_path, person_name)
#       5         embeddings = []
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'path_to_team_images'
